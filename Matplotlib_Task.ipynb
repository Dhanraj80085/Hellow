# %% [markdown]
# # Matplotlib Task

# %% [markdown]
# ## Q1. Install matplotlib and import pyplot as plt

# %%
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Q2. Plot a basic line chart using plt.plot()

# %%
x = [1, 2, 3, 4, 5]
y = [50, 51, 52, 48, 47]

plt.xlabel('Day')
plt.ylabel('SALE')
plt.title('TURNOVER')
plt.plot(x, y, color='blue', linewidth=5, linestyle='-')
plt.show()

# %% [markdown]
# ## Q3. Add title and labels to axes

# %%
plt.xlabel('Day')
plt.ylabel('SALE')
plt.title('TURNOVER')
plt.plot(x, y, color='blue', linewidth=5, linestyle='-')
plt.show()

# %% [markdown]
# ## Q4. Change line color, style, and markers

# %%
plt.plot(x, y, color='green', marker='^', linestyle='')
plt.show()

# %% [markdown]
# ## Q5. Plot multiple lines in the same chart

# %%
days = [1, 2, 3, 4, 5]
maximum_sale = [50, 51, 52, 48, 47]
minimum_sale = [43, 42, 40, 44, 33]
avg_sale = [45, 48, 48, 46, 40]

# %%
plt.xlabel('Day')
plt.ylabel('sale')
plt.title('Turnover')
plt.plot(days, maximum_sale, label="max")
plt.plot(days, minimum_sale, label="min")
plt.plot(days, avg_sale, label="average")
plt.show()

# %% [markdown]
# ## Q6. Add a legend to the chart

# %%
plt.plot(days, maximum_sale,label="max")
plt.plot(days, minimum_sale,label="min")
plt.plot(days, avg_sale,label="average")
plt.legend()
plt.show()

# %% [markdown]
# ## Q7. Save plot as an image file

# %%
plt.savefig('img.png', transparent=None, facecolor='auto', edgecolor='black')
plt.plot(days, maximum_sale,label="max")
plt.plot(days, minimum_sale,label="min")
plt.plot(days, avg_sale,label="average")
plt.show()

# %% [markdown]
# ## Q8. Plot bar chart using plt.bar()

# %%
department = ['Hr', 'IT', 'Sales', 'Marketing']
head_count = [20, 100, 120, 50]

xpos = np.arange(len(department))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos, head_count,label='Head Count')

plt.xticks(xpos, department)
plt.ylabel("Head Count")
plt.title('Department Head Count')
plt.legend()
plt.show()

# %% [markdown]
# ## Q9. Plot a histogram using plt.hist()

# %%
blood_suger = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_suger, rwidth=0.8)
plt.show()

# %% [markdown]
# ## Q10. Plot a pie chart using plt.pie()

# %%
labels = ['Apple', 'Banana', 'Cherry', 'Dates']
sizes = [30, 25, 25, 20]  # Percentages
colors = ['red', 'yellow', 'pink', 'brown']
explode = (0.1, 0, 0, 0)  # "Explode" the 1st slice (Apple)

plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Fruit Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Q11. Use subplots to display multiple plots

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 12, 18, 27]
y2 = [27, 18, 12, 4, 2]

plt.subplot(1, 2, 1)
plt.plot(x, y1, 'r-o')
plt.title('Plot 1')

plt.subplot(1, 2, 2)
plt.plot(x, y1, 'g--s')
plt.title('Plot 2')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q12. Customize ticks and grid lines

# %%
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
plt.legend(loc='lower left', shadow=True, fontsize='small')
plt.show()

# %% [markdown]
# ## Q13. Use different figure sizes

# %%
plt.figure(figsize=(10, 5))
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x, y, 'g-o')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Custom Figure Size')
plt.show()

# %% [markdown]
# ## Q14. Plot a scatter plot using plt.scatter()

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11]
y = [99, 86, 87, 88, 100, 86, 103, 87, 94, 78]

plt.scatter(x, y, color='purple', marker='x')

plt.title("Sample Scatter Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q15. Add annotations to plot points

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.scatter(x, y, color='blue', marker='o')

for i in range(len(x)):
    plt.annotate(f'({x[i]}, {y[i]})', (x[i], y[i]), textcoords="offset points", xytext=(5,5), ha='center')

plt.title("Scatter Plot with Annotations")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q16. Create a stacked bar chart

# %%
labels = ['A', 'B', 'C', 'D']
group1 = [10, 15, 20, 25]
group2 = [5, 10, 5, 15]

plt.bar(labels, group1, label='Group 1')
plt.bar(labels, group2, bottom=group1, label='Group 2')
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Stacked Bar Chart')
plt.legend()
plt.show()

# %% [markdown]
# ## Q17. Change background and axis colors

# %%
plt.plot([1, 2, 3], [4, 5, 6], color='yellow')

ax = plt.gca()
ax.set_facecolor('black')
ax.tick_params(colors='white')
plt.title("Simple Plot", color='white')
plt.show()

# %% [markdown]
# ## Q18. Create a plot with twin axes (twinx/twiny)

# %%
x = [1, 2, 3]
y1 = [1, 4, 9]
y2 = [9, 4, 1]

ax1 = plt.gca()
ax1.plot(x, y1, 'r')
ax2 = ax1.twinx()
ax2.plot(x, y2, 'b')

plt.show()

# %% [markdown]
# ## Q19. Use different styles (e.g., 'ggplot', 'seaborn')

# %%
plt.style.use('ggplot')

x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 14, 16]

plt.plot(x, y, marker='o')
plt.title("Styled Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()
